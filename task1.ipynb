# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('world_population.CSV',  encoding='utf-8')
data.head()
# Out:
#   Country Name Country Code     Indicator Name Indicator Code     1960  \
# 0      Austria          AUT  Population, total    SP.POP.TOTL  7047539
# 1   Azerbaijan          AZE  Population, total    SP.POP.TOTL  3894500
# 2      Burundi          BDI  Population, total    SP.POP.TOTL  2746628
# 3      Belgium          BEL  Population, total    SP.POP.TOTL  9153489
# 4        Benin          BEN  Population, total    SP.POP.TOTL  2512284
#
#       1961     1962     1963     1964     1965  ...      2013      2014  \
# 0  7086299  7129864  7175811  7223801  7270889  ...   8479823   8546356
# 1  4045750  4168150  4293550  4439250  4574650  ...   9416801   9535079
# 2  2815972  2887398  2948133  3033221  3118134  ...  10149577  10494913
# 3  9183948  9220578  9289770  9378113  9463667  ...  11159407  11209057
# 4  2551216  2593302  2638082  2685619  2735843  ...  10308730  10614844
#
#        2015      2016      2017      2018      2019      2020      2021  \
# 0   8642699   8736668   8797566   8840521   8879920   8916864   8955797
# 1   9649341   9757812   9854033   9939771  10024283  10093121  10137750
# 2  10727148  10903327  11155593  11493472  11874838  12220227  12551213
# 3  11274196  11331422  11375158  11427054  11488980  11538604  11586195
# 4  10932783  11260085  11596779  11940683  12290444  12643123  12996895
#
#        2022
# 0   9041851
# 1  10141756
# 2  12889576
# 3  11685814
# 4  13352864
#
# [5 rows x 67 columns]

# %%
data_final = data.drop(['Country Code',	'Indicator Name',	'Indicator Code'], axis=1)

# %%
chosen_country = 'Belgium'


country_data = data_final[data_final['Country Name'] == chosen_country]


years = country_data.columns[2:].astype(int)
population = country_data.iloc[:, 2:].values.flatten()

plt.figure(figsize=(5, 3))
plt.bar(years, population, color='skyblue')
plt.xlabel('Year')
plt.ylabel('Population')
plt.title(f'Population of {chosen_country} Over the Years')
# Out:
# Text(0.5, 1.0, 'Population of Belgium Over the Years')

# %%
plt.hist(population, bins=20, color='skyblue', edgecolor='black')
plt.show()

# %%
# Out:
# Mounted at /content/drive
